# %% [markdown]
# # 案例背景：現有超市購物中心客戶的一些基本數據，如客戶ID,消費金額,訂購金額,訂購時間. 需要解决问题：利用现有资料，划分不同客户类型，以便可以了解哪些客户为超市优质客户，并向营销团队提供意见。 1.Python模型跟數據導入 2.兩種資料格式合併與資料處理 3.最佳商品分析分析 4.銷售時間點分析 5.客單量分析

# %% [markdown]
# # 1.1 Python模型跟數據導入
#
# 使用的庫主要有：pandas、numpy、matplotlib、seaborn 使用的數據集： Order+data+20200629-20200712.csv Order+data+20200713-20200726.csv xiaoshouliushui20200629-0712.xlsx xiaoshouliushui20200713-0726.xlsx

# %% [markdown]
# # 1.2 數據導入並讀取訂單資料
#
# 數據導入並讀取 csv 訂單資料

# %%
import numpy as np                               # 向量和矩阵运算
import pandas as pd                              # 表格与数据处理
import matplotlib.pyplot as plt                  # 绘图
import seaborn as sns                            # 更多绘图功能
sns.set()

from dateutil.relativedelta import relativedelta # 日期数据处理
from scipy.optimize import minimize              # 优化函数

import statsmodels.formula.api as smf            # 数理统计
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

from itertools import product                    # 一些有用的函数
from tqdm import tqdm_notebook

# %% [markdown]
# # 2.1 將兩個月的銷售數據還有訂單內容合併
#
# 使用Concat函式將兩個月的訂單資訊合併

# %%
#Sales with product information 20200629-0712 as file 3
#Sales with product information 20200713-0726 as file 4
files3 = pd.read_excel('/Users/asus/Desktop/FreshGoGo/xiaoshouliushui20200629-0712.xlsx')
files4 = pd.read_excel('/Users/asus/Desktop/FreshGoGo/xiaoshouliushui20200713-0726.xlsx')
#freshgogo1 = pd.read_excel(file3)
#freshgogo2 = pd.read_excel(file4)
files3.head(2)
# Out:
#         下单日期         订单号       送货日期         用户ID     供应商  SKU ID  \
# 0 2020-06-29  1594699128 2020-07-16  55586018823  自营冻品分拣   12095
# 1 2020-06-29  1598776640 2020-07-02  58991718899  自营批发蔬菜   11001
#
#               商品名称（中文）  商品名称（英文）                税类  订购数量   商品单价   税金      总价
# 0  加拿大龙岗走地鸡(冷冻)(拼团)(*)       NaN  Other Categories     5  23.99  0.0  119.95
# 1               芫茜(香菜)       NaN           Grocery     1   1.29  0.0    1.29

# %%
#Sales 20200629-0712 as file 1
#Sales 20200713-0726 as file 2
file1=open(r"/Users/asus/Desktop/FreshGoGo/Order data 20200629-20200712.csv",encoding='utf-8')
file2=open(r"/Users/asus/Desktop/FreshGoGo/Order data 20200713-20200726.csv",encoding='utf-8')
freshgogo1 = pd.read_csv(file1)
freshgogo2 = pd.read_csv(file2)

# %%
frames = [freshgogo1, freshgogo2]
Result = pd.concat(frames)

# %%
freshgogo1.head(2)
# Out:
#    Order Number      Order Time      Cust ID Delivery Date 订单投诉 Status  \
# 0    1594699128  6/29/2020 0:00  55586018823     7/16/2020  NaN    已送达
# 1    1598776640  6/29/2020 0:03  58991718899      7/2/2020  NaN    已送达
#
#    Total Price Payment  Voucher Discount Voucher  ...  Customer Service  \
# 0       119.95   信用卡支付               NaN     NaN  ...               NaN
# 1       147.34   信用卡支付               NaN     NaN  ...               NaN
#
#   OS of App  Unnamed: 17  冷链包装费  支付宝手续费 会员券   配送费 到家/自提  班次  服务费
# 0       ios        2.3.0    1.5     NaN   0  0.00    自提  NY    0
# 1       ios        2.3.0    1.5     NaN   0  6.99    到家  NY    0
#
# [2 rows x 25 columns]

# %%
freshgogo2.head(20)
# Out:
#     Order Number      Order Time         用户ID Delivery Date   订单投诉 Status  \
# 0     1601116468  7/13/2020 0:00  58351892017     7/22/2020    NaN    已送达
# 1     1602472924  7/13/2020 0:01  55085937222     7/18/2020    NaN    已送达
# 2     1599126052  7/13/2020 0:01  56291750175     7/16/2020    NaN    已送达
# 3     1597482400  7/13/2020 0:06  58824880640     7/18/2020  FGG责任  退款已完成
# 4     1595911970  7/13/2020 0:06  53724030573     7/15/2020    NaN    已送达
# 5     1601415235  7/13/2020 0:08  52620173266     7/16/2020    NaN    已送达
# 6     1595158375  7/13/2020 0:10  53085748946     7/18/2020    NaN    已送达
# 7     1601736879  7/13/2020 0:19  58920218907     7/15/2020    NaN    已送达
# 8     1599385615  7/13/2020 0:19  56364660306     7/16/2020    NaN    已送达
# 9     1600061639  7/13/2020 0:19  59741256600     7/16/2020   普通投诉    已送达
# 10    1595300743  7/13/2020 0:20  53692918073     7/16/2020    NaN    已送达
# 11    1600843186  7/13/2020 0:23  53178192425     7/16/2020    NaN    已送达
# 12    1595268427  7/13/2020 0:23  54364627351     7/16/2020    NaN    已送达
# 13    1604220291  7/13/2020 0:24  58971569053     7/16/2020    NaN    已送达
# 14    1604289953  7/13/2020 0:25   5932039245     7/18/2020    NaN    已送达
# 15    1601949218  7/13/2020 0:25   5535182847     7/18/2020    NaN    已送达
# 16    1597830563  7/13/2020 0:29   5204126118     7/24/2020    NaN    已送达
# 17    1601890870  7/13/2020 0:30  53664659431     7/18/2020    NaN    已送达
# 18    1598129812  7/13/2020 0:36   5372405826     7/15/2020    NaN    已送达
# 19    1594887324  7/13/2020 0:40  55864675072     7/16/2020    NaN    已送达
#
#     Total Price Payment  Voucher Discount Voucher  ...  Customer Service  \
# 0        118.18   信用卡支付               NaN     NaN  ...            R-商品变质
# 1        298.84    余额支付               NaN     NaN  ...               NaN
# 2        165.81   信用卡支付               NaN     NaN  ...               NaN
# 3        174.53   信用卡支付               NaN     NaN  ...            R-商品变质
# 4        207.03   信用卡支付               NaN     NaN  ...              R-其他
# 5        199.14    余额支付               NaN     NaN  ...               NaN
# 6        171.39   信用卡支付               NaN     NaN  ...               NaN
# 7        264.84   信用卡支付               NaN     NaN  ...               NaN
# 8        100.46  PayPal               NaN     NaN  ...               NaN
# 9        190.00    余额支付               NaN     NaN  ...            R-包装损坏
# 10       101.42   信用卡支付               NaN     NaN  ...               NaN
# 11       134.10  PayPal               NaN     NaN  ...               NaN
# 12       178.36  PayPal               NaN     NaN  ...               NaN
# 13       142.69   信用卡支付               NaN     NaN  ...         R-数量/重量不符
# 14       126.68    余额支付               NaN     NaN  ...               NaN
# 15        72.94   信用卡支付               NaN     NaN  ...               NaN
# 16       236.34  PayPal               NaN     NaN  ...               NaN
# 17       299.62    余额支付               NaN     NaN  ...         R-数量/重量不符
# 18       253.29   信用卡支付               NaN     NaN  ...               NaN
# 19       213.45   信用卡支付               NaN     NaN  ...               NaN
#
#    OS of App  Unnamed: 17  冷链包装费  支付宝手续费 会员券   配送费 到家/自提      班次  服务费
# 0        ios        2.3.1    1.5     NaN   5  0.00    自提      DC    0
# 1        ios        2.3.1    1.5     NaN   5  0.00    自提      OT    0
# 2       pc下单          NaN    1.5     NaN   0  9.99    到家      NY    0
# 3        ios        2.3.1    1.5     NaN   0  0.00    自提      OT    0
# 4       pc下单          NaN    1.5     NaN   0  6.99    到家      DC    0
# 5        ios        2.3.1    1.5     NaN   5  9.99    到家      NY    0
# 6        ios        2.3.1    NaN     NaN   0  9.99    到家  Boston    0
# 7       pc下单          NaN    1.5     NaN   0  6.99    到家      DC    0
# 8        ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
# 9        ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
# 10       ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
# 11       ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
# 12      pc下单          NaN    1.5     NaN   0  0.00    自提      NY    0
# 13       ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
# 14   android        2.3.1    1.5     NaN   5  0.00    自提      NY    0
# 15       ios        2.3.1    1.5     NaN   0  0.00    自提      OT    0
# 16      pc下单          NaN    1.5     NaN   0  0.00    自提      NY    0
# 17       ios        2.3.1    1.5     1.5   0  0.00    自提      OT    0
# 18       ios        2.3.1    1.5     NaN   0  6.99    到家      DC    0
# 19       ios        2.3.1    1.5     NaN   0  9.99    到家      NY    0
#
# [20 rows x 25 columns]

# %%
frames = [freshgogo1, freshgogo2]
result = pd.concat(frames)

# %%
Result.isnull().sum(axis=0)
# Out:
# Order Number            0
# Order Time              0
# Cust ID             11956
# Delivery Date           0
# 订单投诉                23015
# Status                  0
# Total Price             0
# Payment                 0
# Voucher Discount    23345
# Voucher             23345
# Coupon Discount     23996
# Coupon              23996
# Tax Price               0
# Final Price             0
# Refund              11289
# Customer Service    22536
# OS of App               0
# Unnamed: 17          6058
# 冷链包装费                2914
# 支付宝手续费              22511
# 会员券                     0
# 配送费                     0
# 到家/自提                   0
# 班次                      0
# 服务费                     0
# 用户ID                12094
# dtype: int64

# %% [markdown]
# 將資料重新命名

# %%
Result.rename(columns={"订单投诉":"complaint","会员券":"membership","配送费":"delivery_fee","到家/自提":"Delivery/Pick_up"},inplace=True)

# %% [markdown]
# # 2.2 將兩個月的產品銷售數據訂單合併

# %%
frames2 = [files3, files4]
Product = pd.concat(frames2)
Product.head(2)
# Out:
#         下单日期         订单号       送货日期         用户ID     供应商  SKU ID  \
# 0 2020-06-29  1594699128 2020-07-16  55586018823  自营冻品分拣   12095
# 1 2020-06-29  1598776640 2020-07-02  58991718899  自营批发蔬菜   11001
#
#               商品名称（中文）  商品名称（英文）                税类  订购数量   商品单价   税金      总价
# 0  加拿大龙岗走地鸡(冷冻)(拼团)(*)       NaN  Other Categories     5  23.99  0.0  119.95
# 1               芫茜(香菜)       NaN           Grocery     1   1.29  0.0    1.29

# %% [markdown]
# # 2.3 將訂單資訊跟產品銷售數據訂單合併 Group By Two Dataframe Table via Order ID
# The First Dataframe is " Result " dataframe and "Product" is about product infomation.

# %%
#如果left Join 依據左表格 Number ID, 找兩者交集只有436661筆資料, 因此選擇how="left" 產生448852筆資料
df = pd.merge(Result,Product,how="left") 
df.head(3)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 448852 entries, 0 to 448851
# Data columns (total 38 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order Number      448852 non-null  int64
#  1   Order Time        448852 non-null  object
#  2   Cust ID           12094 non-null   float64
#  3   Delivery Date     448852 non-null  object
#  4   complaint         17125 non-null   object
#  5   Status            448852 non-null  object
#  6   Total Price       448852 non-null  float64
#  7   Payment           448852 non-null  object
#  8   Voucher Discount  9420 non-null    float64
#  9   Voucher           9420 non-null    object
#  10  Coupon Discount   843 non-null     float64
#  11  Coupon            843 non-null     object
#  12  Tax Price         448852 non-null  float64
#  13  Final Price       448852 non-null  float64
#  14  Refund            260944 non-null  float64
#  15  Customer Service  23999 non-null   object
#  16  OS of App         448852 non-null  object
#  17  Unnamed: 17       336730 non-null  object
#  18  冷链包装费             406423 non-null  float64
#  19  支付宝手续费            28050 non-null   float64
#  20  membership        448852 non-null  int64
#  21  delivery_fee      448852 non-null  float64
#  22  Delivery/Pick_up  448852 non-null  object
#  23  班次                448852 non-null  object
#  24  服务费               448852 non-null  int64
#  25  用户ID              436758 non-null  float64
#  26  下单日期              436661 non-null  datetime64[ns]
#  27  订单号               436661 non-null  float64
#  28  送货日期              436661 non-null  datetime64[ns]
#  29  供应商               436661 non-null  object
#  30  SKU ID            436661 non-null  float64
#  31  商品名称（中文）          436661 non-null  object
#  32  商品名称（英文）          0 non-null       float64
#  33  税类                435239 non-null  object
#  34  订购数量              436661 non-null  float64
#  35  商品单价              436661 non-null  float64
#  36  税金                436661 non-null  float64
#  37  总价                436661 non-null  float64
# dtypes: datetime64[ns](2), float64(18), int64(3), object(15)
# memory usage: 133.6+ MB

# %% [markdown]
# #如果 Join 依據左表格 Number ID, 找兩者交集只有436661筆資料, 因此選擇how="left" 產生448852筆資料（修正）

# %% [markdown]
# ＃數據清理參考需要跟團隊討論後修正

# %%
#如果想要用 mean / median 等數字填充,可以使用 fillna() ，後面加上特定的公式帶入。
# Calculate the mean of the delivery_fee column: delivery_fee
delivery_fee_mean = df.delivery_fee.mean()
# Replace all the missing values in the Ozone column with the mean
df['delivery_fee'] = df.delivery_fee.fillna(delivery_fee_mean)
# Print the info of airquality
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 448852 entries, 0 to 448851
# Data columns (total 38 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order Number      448852 non-null  int64
#  1   Order Time        448852 non-null  object
#  2   Cust ID           12094 non-null   float64
#  3   Delivery Date     448852 non-null  object
#  4   complaint         17125 non-null   object
#  5   Status            448852 non-null  object
#  6   Total Price       448852 non-null  float64
#  7   Payment           448852 non-null  object
#  8   Voucher Discount  9420 non-null    float64
#  9   Voucher           9420 non-null    object
#  10  Coupon Discount   843 non-null     float64
#  11  Coupon            843 non-null     object
#  12  Tax Price         448852 non-null  float64
#  13  Final Price       448852 non-null  float64
#  14  Refund            260944 non-null  float64
#  15  Customer Service  23999 non-null   object
#  16  OS of App         448852 non-null  object
#  17  Unnamed: 17       336730 non-null  object
#  18  冷链包装费             406423 non-null  float64
#  19  支付宝手续费            28050 non-null   float64
#  20  membership        448852 non-null  int64
#  21  delivery_fee      448852 non-null  float64
#  22  Delivery/Pick_up  448852 non-null  object
#  23  班次                448852 non-null  object
#  24  服务费               448852 non-null  int64
#  25  用户ID              436758 non-null  float64
#  26  下单日期              436661 non-null  datetime64[ns]
#  27  订单号               436661 non-null  float64
#  28  送货日期              436661 non-null  datetime64[ns]
#  29  供应商               436661 non-null  object
#  30  SKU ID            436661 non-null  float64
#  31  商品名称（中文）          436661 non-null  object
#  32  商品名称（英文）          0 non-null       float64
#  33  税类                435239 non-null  object
#  34  订购数量              436661 non-null  float64
#  35  商品单价              436661 non-null  float64
#  36  税金                436661 non-null  float64
#  37  总价                436661 non-null  float64
# dtypes: datetime64[ns](2), float64(18), int64(3), object(15)
# memory usage: 133.6+ MB
# None

# %% [markdown]
# # 3.1 暢銷商品分析

# %%
df["Sales"]=df["总价"]
df["Product"]=df["商品名称（中文）"]
df["Supplier"]=df["供应商"]

# %%
Product_Sales = df.groupby(["Product",'Supplier']).agg({'Sales':'sum'})
Product_Sales["percent"] = Product_Sales["Sales"] /df["Sales"].sum()
Product_Sales.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_707b5516_dca8_11ea_b715_20c9d078ed2brow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow1_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow1_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow2_col0 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow2_col1 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow3_col0 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow3_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow4_col0 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow4_col1 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow5_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow5_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow6_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow6_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow7_col0 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow7_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow8_col0 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow8_col1 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow9_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow9_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow10_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow10_col1 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow11_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow11_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow12_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow12_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow13_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow13_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow14_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow14_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow15_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow15_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow16_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow16_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow17_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow17_col1 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow18_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow18_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow19_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow19_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow20_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow20_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow21_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow21_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow22_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow22_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow23_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow23_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow24_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow24_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow25_col0 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow25_col1 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow26_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow26_col1 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow27_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow27_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow28_col0 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow28_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow29_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_707b5516_dca8_11ea_b715_20c9d078ed2brow29_col1 {
#             background-color:  #

# %%
Supplier_Sales=df.groupby(["Supplier"]).agg({"Sales":"sum"})
Supplier_Sales.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e866e130_dca8_11ea_b715_20c9d078ed2brow0_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow5_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow6_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow7_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow9_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow10_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow11_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow12_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow13_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow14_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow15_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow16_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow17_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow18_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow19_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow20_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow21_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow22_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow23_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow24_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow25_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow26_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow27_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow28_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow29_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow30_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow31_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow32_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow33_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow34_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow35_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow36_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow37_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow38_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow39_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow40_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow41_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow42_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow43_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow44_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow45_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow46_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow47_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow48_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow49_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow50_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow51_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow52_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow53_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow54_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow55_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow56_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow57_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow58_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_e866e130_dca8_11ea_b715_20c9d078ed2brow59_col0 {
#             background

# %%
# 销量top10 商品
productId_count = df.groupby('商品名称（中文）').count()['用户ID'].sort_values(ascending=False)
print(productId_count.head(10))
# Out:
# 商品名称（中文）
# 葱(低价)       7293
# 莴苣          4327
# 绍菜(低价)      3963
# 中国茄子(低价)    3819
# 番茄(低价)      3656
# 上海菜(低价)     3458
# 蒜头(低价)      3233
# 姜(低价)       3203
# 上海苗(低价)     3173
# 空心菜         3125
# Name: 用户ID, dtype: int64

# %%
#销售额top10商品
productId_amount = df.groupby('商品名称（中文）').sum()['Sales'].sort_values(ascending=False)
print(productId_amount.head(10))
 
#销售额top10 供應商
productId_Profit = df.groupby('Supplier').sum()['Sales'].sort_values(ascending=False)
print(productId_Profit.head(10))
# Out:
# 商品名称（中文）
# 肥牛肉片                 29392.82
# 散装黑叶荔枝(限量)           25224.68
# 金钱腱(低价)              23468.21
# (1.5磅)金沙骨(低价)        21891.98
# 绍菜(低价)               21029.46
# 招牌鱼饺(冷冻)(限量)【鱼饺子】    18495.72
# 空心菜                  18381.60
# 莴苣                   17264.13
# 天津黄瓜                 16967.11
# 无骨五花肉(低价)            16654.98
# Name: Sales, dtype: float64
# Supplier
# FreshGoGo自营    1.215272e+06
# 自营批发蔬菜         7.704000e+05
# 自营冻品分拣         7.638637e+04
# 德昌肉品           6.209111e+04
# 老豫园-冷冻         6.142827e+04
# 凯诗琳            5.668518e+04
# 上海豫园           4.207482e+04
# 鱼饺子-冷冻         3.958217e+04
# 大班饼店           3.717856e+04
# 老北京            3.693188e+04
# Name: Sales, dtype: float64

# %% [markdown]
# # 4.1 銷售時間點分析

# %%
dt= result['Order Time'].astype(str) #转换成字符串格式

# %%
from datetime import datetime

# %%
dt = dt.apply(lambda x:datetime.strptime(x,'%m/%d/%Y %H:%M'))

# %%
result['month'] = dt.map(lambda x: x.month) #获取月份，并添加列month
result['year'] = dt.map(lambda x: x.year)
result['day'] = dt.map(lambda x: x.day)
result['hour'] = dt.map(lambda x: x.hour)
result['minute'] = dt.map(lambda x: x.minute)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24050 entries, 0 to 11955
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Number      24050 non-null  int64
#  1   Order Time        24050 non-null  object
#  2   Cust ID           12094 non-null  float64
#  3   Delivery Date     24050 non-null  object
#  4   订单投诉              1035 non-null   object
#  5   Status            24050 non-null  object
#  6   Total Price       24050 non-null  float64
#  7   Payment           24050 non-null  object
#  8   Voucher Discount  705 non-null    float64
#  9   Voucher           705 non-null    object
#  10  Coupon Discount   54 non-null     float64
#  11  Coupon            54 non-null     object
#  12  Tax Price         24050 non-null  float64
#  13  Final Price       24050 non-null  float64
#  14  Customer Service  1514 non-null   object
#  15  OS of App         24050 non-null  object
#  16  冷链包装费             21136 non-null  float64
#  17  会员券               24050 non-null  int64
#  18  配送费               24050 non-null  float64
#  19  到家/自提             24050 non-null  object
#  20  班次                24050 non-null  object
#  21  服务费               24050 non-null  int64
#  22  用户ID              11956 non-null  float64
#  23  month             24050 non-null  int64
#  24  year              24050 non-null  int64
#  25  day               24050 non-null  int64
#  26  hour              24050 non-null  int64
#  27  minute            24050 non-null  int64
# dtypes: float64(9), int64(8), object(11)
# memory usage: 5.3+ MB

# %%
#对data进行按Order Date日期进行排序
fg_result=df.sort_values(by='Order Time',ascending=True,na_position='first')#把转化异常的数据放上面

# %%
#选取销售分析数据子集
sales_data=result[['Order Time','Total Price','Final Price','year','month','day','minute']]
sales_data.head()
# Out:
#        Order Time  Total Price  Final Price  year  month  day  minute
# 0  6/29/2020 0:00       119.95       121.45  2020      6   29       0
# 1  6/29/2020 0:03       147.34       160.29  2020      6   29       3
# 2  6/29/2020 0:04        89.30        86.53  2020      6   29       4
# 3  6/29/2020 0:04        45.45        59.18  2020      6   29       4
# 4  6/29/2020 0:08       247.80       262.20  2020      6   29       8

# %%
sales_year = sales_data.groupby(['year','month']).sum()
sales_year
# Out:
#             Total Price  Final Price     day  minute
# year month
# 2020 6        227987.04    242263.65   51723   51958
#      7       2818611.16   2994082.08  297515  668691

# %%
import seaborn as sns

# %%
sales = pd.read_csv('/Users/asus/Desktop/FreshGoGo/Order data 20200629-20200712.csv', index_col=['Order Time'], parse_dates=['Order Time'])
sales.head()
# Out:
#                      Order Number      Cust ID Delivery Date   订单投诉 Status  \
# Order Time
# 2020-06-29 00:00:00    1594699128  55586018823     7/16/2020    NaN    已送达
# 2020-06-29 00:03:00    1598776640  58991718899      7/2/2020    NaN    已送达
# 2020-06-29 00:04:00    1597710951  57851868718      7/4/2020    NaN    已送达
# 2020-06-29 00:04:00    1595995162  58431571996      7/2/2020    NaN    已送达
# 2020-06-29 00:08:00    1602053507  59691743730      7/5/2020  FGG责任    已送达
#
#                      Total Price Payment  Voucher Discount  \
# Order Time
# 2020-06-29 00:00:00       119.95   信用卡支付               NaN
# 2020-06-29 00:03:00       147.34   信用卡支付               NaN
# 2020-06-29 00:04:00        89.30   信用卡支付               5.0
# 2020-06-29 00:04:00        45.45  PayPal               NaN
# 2020-06-29 00:08:00       247.80   信用卡支付               NaN
#
#                                                    Voucher  Coupon Discount  \
# Order Time
# 2020-06-29 00:00:00                                    NaN              NaN
# 2020-06-29 00:03:00                                    NaN              NaN
# 2020-06-29 00:04:00  新FAF【邀请有礼】【被邀请人】满$25减$5 活动至20201231结束              NaN
# 2020-06-29 00:04:00                                    NaN              NaN
# 2020-06-29 00:08:00                                    NaN              NaN
#
#                      ... Customer Service  OS of App  Unnamed: 17  冷链包装费  \
# Order Time           ...
# 2020-06-29 00:00:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:03:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:04:00  ...              NaN    android        2.3.0    1.5
# 2020-06-29 00:04:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:08:00  ...           R-质量问题        ios        2.3.0    1.5
#
#                     支付宝手续费 会员券   配送费  到家/自提  班次  服务费
# Order Time
# 2020-06-29 00:00:00    NaN   0  0.00     自提  NY    0
# 2020-06-29 00:03:00    NaN   0  6.99     到家  NY    0
# 2020-06-29 00:04:00    NaN   0  0.00     自提  OT    0
# 2020-06-29 00:04:00    NaN   0  9.99     到家  NY    2
# 2020-06-29 00:08:00    NaN   0  9.99     到家  NY    0
#
# [5 rows x 24 columns]

# %% [markdown]
# # 5.客單量分析
#
# 客單價是指商場（超市）每一個顧客平均購買商品的金額，客單價也即是平均交易金額。 從某種程度上反映了企業的消費群體的許多特點以及企業的銷售類目的盈利狀態是否健康。 總消費次數：同一天內，同一個人發生的所有消費算作一次消費。
# 客單價=總消費金額 / 總消費次數

# %%
price=df[['Order Time','Cust ID','Sales','订购数量']]

# %%
price.rename(columns={"Order Time":"order_time"},inplace=True)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# 計算總消費次數
price_dr=price.drop_duplicates(subset=['order_time', 'Cust ID'])
# 總消費次數：有多少行
total_num=price_dr.shape[0]
print('兩個月總消費次數=',total_num)
unit_price = price['Sales'].sum()/total_num
print('兩個月客單價=', unit_price,'\n')
# Out:
# 兩個月總消費次數= 20320
# 兩個月客單價= 153.11689271653543

# %%
grouped_Customer = price[['Cust ID','order_time','Sales']].sort_values(['order_time']).groupby('Cust ID') 
grouped_Customer.head()
# Out:
#            Cust ID      order_time  Sales
# 0     5.558602e+10  6/29/2020 0:00    NaN
# 1     5.899172e+10  6/29/2020 0:03    NaN
# 2     5.785187e+10  6/29/2020 0:04    NaN
# 3     5.843157e+10  6/29/2020 0:04    NaN
# 4     5.969174e+10  6/29/2020 0:08    NaN
# ...            ...             ...    ...
# 8940  5.236078e+10   7/9/2020 9:55    NaN
# 8941  5.788069e+10   7/9/2020 9:56    NaN
# 8942  5.457743e+10   7/9/2020 9:57    NaN
# 8943  5.696464e+10   7/9/2020 9:58    NaN
# 8944  5.428453e+10   7/9/2020 9:59    NaN
#
# [12066 rows x 3 columns]

# %%
#看一下用戶的第一次購買日期分布
grouped_Customer.min().order_time.value_counts().plot(figsize=(20,5))

# %%
#再來看一下用戶的最後一次購買日期分布
grouped_Customer.max().order_time.value_counts().plot(figsize=(20,5))

# %% [markdown]
# 再來看看只購買過一次的客戶數量 ：

# %%
# 統計每個客戶第一次和最後一次購買記錄
Customer_life = grouped_Customer.order_time.agg(['min','max'])

# %%
# 查看只有一次購買記錄的顧客數量，第一次和最後一次是同一條記錄，則說明購買只有一次
(Customer_life['min'] == Customer_life['max']).value_counts()
# Out:
# True     7777
# False    1895
# dtype: int64

# %% [markdown]
# 從結果來看，只購買一次的用戶有7777個，大部分用戶都會購買多次，說明回頭率很低， 也驗證了上面關於該企業老客戶的維繫不夠的結論。

# %% [markdown]
# RFM的含義：
# R（Recency）：客戶最近一次交易時間的間隔。R值越大，表示客戶交易發生的日期越久，反之則表示客戶交易發生的日期越近。
# F（Frequency）：客戶在最近一段時間內交易的次數。F值越大，表示客戶交易越頻繁，反之則表示客戶交易不夠活躍。
# M（Monetary）：客戶在最近一段時間內交易的金額。M值越大，表示客戶價值越高，反之則表示客戶價值越低。
# RFM分析就是根據客戶活躍程度和交易金額的貢獻，進行客戶價值細分的一種方法。
# 首先構建RFM表：

# %%
rfm[['R','F','M']].apply(lambda x:x-x.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-d498cd973dcf> in <module>
# ----> 1 rfm[['R','F','M']].apply(lambda x:x-x.mean())
#
# NameError: name 'rfm' is not defined

# %%
def rfm_func(x): 
    level =x.apply(lambda x:'1'if x>0 else '0') 
    level =level.R +level.F +level.M 
    d = { "111":"重要價值客戶", "011":"重要保持客戶", "101":"重要挽留客戶", "001":"重要發展客戶", "110":"一般價值客戶", "010":"一般保持客戶", "100":"一般挽留客戶", "000":"一般發展客戶" } 
    result = d[level] 
    return result

# %%
result.to_pickle('/Users/asus/Desktop/FreshGoGo/Order data 20200629-20200726.xlsx')

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24050 entries, 0 to 11955
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Number      24050 non-null  int64
#  1   Order Time        24050 non-null  object
#  2   Cust ID           12094 non-null  float64
#  3   Delivery Date     24050 non-null  object
#  4   订单投诉              1035 non-null   object
#  5   Status            24050 non-null  object
#  6   Total Price       24050 non-null  float64
#  7   Payment           24050 non-null  object
#  8   Voucher Discount  705 non-null    float64
#  9   Voucher           705 non-null    object
#  10  Coupon Discount   54 non-null     float64
#  11  Coupon            54 non-null     object
#  12  Tax Price         24050 non-null  float64
#  13  Final Price       24050 non-null  float64
#  14  Refund            12761 non-null  float64
#  15  Customer Service  1514 non-null   object
#  16  OS of App         24050 non-null  object
#  17  Unnamed: 17       17992 non-null  object
#  18  冷链包装费             21136 non-null  float64
#  19  支付宝手续费            1539 non-null   float64
#  20  会员券               24050 non-null  int64
#  21  配送费               24050 non-null  float64
#  22  到家/自提             24050 non-null  object
#  23  班次                24050 non-null  object
#  24  服务费               24050 non-null  int64
#  25  用户ID              11956 non-null  float64
# dtypes: float64(11), int64(3), object(12)
# memory usage: 5.0+ MB

# %%
result.drop(["Unnamed: 17","Refund","支付宝手续费"],axis=1, inplace=True)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24050 entries, 0 to 11955
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Number      24050 non-null  int64
#  1   Order Time        24050 non-null  object
#  2   Cust ID           12094 non-null  float64
#  3   Delivery Date     24050 non-null  object
#  4   订单投诉              1035 non-null   object
#  5   Status            24050 non-null  object
#  6   Total Price       24050 non-null  float64
#  7   Payment           24050 non-null  object
#  8   Voucher Discount  705 non-null    float64
#  9   Voucher           705 non-null    object
#  10  Coupon Discount   54 non-null     float64
#  11  Coupon            54 non-null     object
#  12  Tax Price         24050 non-null  float64
#  13  Final Price       24050 non-null  float64
#  14  Customer Service  1514 non-null   object
#  15  OS of App         24050 non-null  object
#  16  冷链包装费             21136 non-null  float64
#  17  会员券               24050 non-null  int64
#  18  配送费               24050 non-null  float64
#  19  到家/自提             24050 non-null  object
#  20  班次                24050 non-null  object
#  21  服务费               24050 non-null  int64
#  22  用户ID              11956 non-null  float64
# dtypes: float64(9), int64(3), object(11)
# memory usage: 4.4+ MB

# %%
dt
# Out:
# 0         6/29/2020 0:00
# 1         6/29/2020 0:03
# 2         6/29/2020 0:04
# 3         6/29/2020 0:04
# 4         6/29/2020 0:08
#               ...
# 11951    7/26/2020 23:55
# 11952    7/26/2020 23:57
# 11953    7/26/2020 23:58
# 11954    7/26/2020 23:59
# 11955    7/26/2020 23:59
# Name: Order Time, Length: 24050, dtype: object

# %%
sales_year = sales_data.groupby(['year','month']).sum()
sales_year
# Out:
#             Total Price  Final Price     day  minute
# year month
# 2020 6        227987.04    242263.65   51723   51958
#      7       2818611.16   2994082.08  297515  668691

# %%
import seaborn as sns

# %%
sales = pd.read_csv('/Users/asus/Desktop/FreshGoGo/Order data 20200629-20200712.csv', index_col=['Order Time'], parse_dates=['Order Time'])
sales.head()
# Out:
#                      Order Number      Cust ID Delivery Date   订单投诉 Status  \
# Order Time
# 2020-06-29 00:00:00    1594699128  55586018823     7/16/2020    NaN    已送达
# 2020-06-29 00:03:00    1598776640  58991718899      7/2/2020    NaN    已送达
# 2020-06-29 00:04:00    1597710951  57851868718      7/4/2020    NaN    已送达
# 2020-06-29 00:04:00    1595995162  58431571996      7/2/2020    NaN    已送达
# 2020-06-29 00:08:00    1602053507  59691743730      7/5/2020  FGG责任    已送达
#
#                      Total Price Payment  Voucher Discount  \
# Order Time
# 2020-06-29 00:00:00       119.95   信用卡支付               NaN
# 2020-06-29 00:03:00       147.34   信用卡支付               NaN
# 2020-06-29 00:04:00        89.30   信用卡支付               5.0
# 2020-06-29 00:04:00        45.45  PayPal               NaN
# 2020-06-29 00:08:00       247.80   信用卡支付               NaN
#
#                                                    Voucher  Coupon Discount  \
# Order Time
# 2020-06-29 00:00:00                                    NaN              NaN
# 2020-06-29 00:03:00                                    NaN              NaN
# 2020-06-29 00:04:00  新FAF【邀请有礼】【被邀请人】满$25减$5 活动至20201231结束              NaN
# 2020-06-29 00:04:00                                    NaN              NaN
# 2020-06-29 00:08:00                                    NaN              NaN
#
#                      ... Customer Service  OS of App  Unnamed: 17  冷链包装费  \
# Order Time           ...
# 2020-06-29 00:00:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:03:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:04:00  ...              NaN    android        2.3.0    1.5
# 2020-06-29 00:04:00  ...              NaN        ios        2.3.0    1.5
# 2020-06-29 00:08:00  ...           R-质量问题        ios        2.3.0    1.5
#
#                     支付宝手续费 会员券   配送费  到家/自提  班次  服务费
# Order Time
# 2020-06-29 00:00:00    NaN   0  0.00     自提  NY    0
# 2020-06-29 00:03:00    NaN   0  6.99     到家  NY    0
# 2020-06-29 00:04:00    NaN   0  0.00     自提  OT    0
# 2020-06-29 00:04:00    NaN   0  9.99     到家  NY    2
# 2020-06-29 00:08:00    NaN   0  9.99     到家  NY    0
#
# [5 rows x 24 columns]

# %%
sales_data=sales[['Total Price','Final Price']]
sales_data.head()
# Out:
#                      Total Price  Final Price
# Order Time
# 2020-06-29 00:00:00       119.95       121.45
# 2020-06-29 00:03:00       147.34       160.29
# 2020-06-29 00:04:00        89.30        86.53
# 2020-06-29 00:04:00        45.45        59.18
# 2020-06-29 00:08:00       247.80       262.20

# %%
sales_data.columns=['Total','Final']

# %%
plt.figure(figsize=(30, 10))
plt.plot(sales_data.Total)
plt.title('Fresh Go Go(hourly data)')
plt.grid(True)
plt.show()
